# %%
import numpy as np
np.__version__
# Out:
# '1.21.6'

# %% [markdown]
# ## Arreglos Lineales (Vectores)

# %%
# Lista
[12,11,5,15,14,20,16]
# Out:
# [12, 11, 5, 15, 14, 20, 16]

# %%
# Array
notas=np.array([12,11,5,15,14,20,16]) # Vector Fila
notas
# Out:
# array([12, 11,  5, 15, 14, 20, 16])

# %%
notas.shape
# Out:
# (7,)

# %%
notas2=notas.reshape(-1,1) # Vector Columna
notas2
# Out:
# array([[12],
#        [11],
#        [ 5],
#        [15],
#        [14],
#        [20],
#        [16]])

# %%
notas2.shape
# Out:
# (7, 1)

# %%
# Acceso & Slicing
notas[2],notas[2:],notas[:2],notas[:-1]  # Similar a las listas
# Out:
# (5,
#  array([ 5, 15, 14, 20, 16]),
#  array([12, 11]),
#  array([12, 11,  5, 15, 14, 20]))
