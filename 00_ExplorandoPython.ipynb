# %% [markdown]
# # Explorando Python

# %% [markdown]
# ## Python As Calculator

# %%
# Nros Reales
(abs(3+5)+abs(3-5))/2 # Mayor entre 3 y 5
# Out:
# 5.0

# %%
# Nros Complejos
3+4j
# Out:
# (3+4j)

# %%
# Arreglos
import numpy as np
np.array([12,5,18,13,17])**2
# Out:
# array([144,  25, 324, 169, 289])

# %% [markdown]
# ## Python As Programing Lenguaje

# %%
for i in range(1,11):
  print(i,i**2,i**3)
# Out:
# 1 1 1
# 2 4 8
# 3 9 27
# 4 16 64
# 5 25 125
# 6 36 216
# 7 49 343
# 8 64 512
# 9 81 729
# 10 100 1000

# %% [markdown]
# ## Python AS Graphic Tools

# %%
import matplotlib.pyplot as plt
x=np.linspace(-3.5,3.5,100)#[1,2,3,4,5,6,7,8,9]
y=np.sin(x)
plt.plot(x,y)

# %%
x
# Out:
# array([-3.5       , -3.42929293, -3.35858586, -3.28787879, -3.21717172,
#        -3.14646465, -3.07575758, -3.00505051, -2.93434343, -2.86363636,
#        -2.79292929, -2.72222222, -2.65151515, -2.58080808, -2.51010101,
#        -2.43939394, -2.36868687, -2.2979798 , -2.22727273, -2.15656566,
#        -2.08585859, -2.01515152, -1.94444444, -1.87373737, -1.8030303 ,
#        -1.73232323, -1.66161616, -1.59090909, -1.52020202, -1.44949495,
#        -1.37878788, -1.30808081, -1.23737374, -1.16666667, -1.0959596 ,
#        -1.02525253, -0.95454545, -0.88383838, -0.81313131, -0.74242424,
#        -0.67171717, -0.6010101 , -0.53030303, -0.45959596, -0.38888889,
#        -0.31818182, -0.24747475, -0.17676768, -0.10606061, -0.03535354,
#         0.03535354,  0.10606061,  0.17676768,  0.24747475,  0.31818182,
#         0.38888889,  0.45959596,  0.53030303,  0.6010101 ,  0.67171717,
#         0.74242424,  0.81313131,  0.88383838,  0.95454545,  1.02525253,
# ...

# %% [markdown]
# ## Mecanismos I/O

# %%
# Salida
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
# Entrada
input("Ingrese un Dato: ")
# Out:
# Ingrese un Dato: 12
# '12'

# %%
nombre=input("Ingresa tu nombre: ")
# Out:
# Ingresa tu nombre: JOSE

# %%
nombre
# Out:
# 'JOSE'

# %%
# Programa Saludo
nombre=input("Ingresa tu nombre: ")
print("Bienvenido",nombre)
# Out:
# Ingresa tu nombre: BREYSON
# Bienvenido BREYSON

# %%
# Dado dos numeros indicar el menor
x=int(input("Ingrese el 1er numero: "))
y=int(input("Ingrese el 2do numero: "))
menor=(abs(x+y)-abs(x-y))/2
print("El menor de",x,"y",y,"es",menor)
# Out:
# Ingrese el 1er numero: 12
# Ingrese el 2do numero: 15
# El menor de 12 y 15 es 12.0
